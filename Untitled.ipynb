# %% [markdown]
# <a href="https://colab.research.google.com/github/ADVIKA01/AdvikaMarantu_ML_Internship_2026/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#sum
sum_num=sum(range(1,11))
print(f"Sum of first 10 natural numbers is:{sum_num}")

#factorial
num=int(input("Enter a number:"))
fact=1
for i in range(1,num+1):
 fact*=i
print(f"Factorial:{fact}")

#fibonacci series
terms=int(input("How many terms?"))
n1,n2=0,1
count=0
print("Fibonacci sequence:")
while count < terms:
 print(n1,end="")
nth=n1+n2
n1=n2
n2=nth
count+=1

#largest number
num1 = int(input("Enter a first number : "))
num2 = int(input("Enter a second number : "))
num3 = int(input("Enter a third number : "))
if num1>num2 and num1>num3:
  print(f"First number ({num1}) is the largest.")
elif num2>num1 and num2>num3:
  print(f"Second number ({num2}) is the largest.")
else:
  print(f"Third number ({num3}) is the largest.")
# Out:
# Sum of first 10 natural numbers is:55
# Enter a number:4
# Factorial:1
# Factorial:2
# Factorial:6
# Factorial:24
# How many terms?5
# Fibonacci sequence:
# 01123Enter a first number : 6
# Enter a second number : 7
# Enter a third number : 5
# Second number (7) is the largest.

# %%
#Student system
print("Enter Student Details")
name=input("Enter student name:")
roll=input("Enter roll number:")
print("\nEnter marks for 5 subjects:")
sub1=float(input("Subject1:"))
sub2=float(input("Subject2:"))
sub3=float(input("Subject3:"))
sub4=float(input("Subject4:"))
sub5=float(input("Subject5:"))
total=sub1+sub2+sub3+sub4+sub5
percentage=total/5
if percentage>=90:
 grade="A+"
elif percentage>=80:
 grade="A"
elif percentage>=70:
 grade="B"
elif percentage>=60:
 grade="C"
elif percentage>=50:
 grade="D"
else:
 grade="Fail"
print("\nResult")
print("Name:",name)
print("Roll No:",roll)
print("Total Marks:",total)
print("Percentage:",percentage)
print("Grade:",grade)
# Out:
# Enter Student Details
# Enter student name:Advika
# Enter roll number:11
#
# Enter marks for 5 subjects:
# Subject1:78
# Subject2:83
# Subject3:76
# Subject4:75
# Subject5:78
#
# Result
# Name: Advika
# Roll No: 11
# Total Marks: 390.0
# Percentage: 78.0
# Grade: B
