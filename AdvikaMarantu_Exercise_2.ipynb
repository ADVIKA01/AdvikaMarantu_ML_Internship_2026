# %% [markdown]
# <a href="https://colab.research.google.com/github/ADVIKA01/AdvikaMarantu_ML_Internship_2026/blob/main/AdvikaMarantu_Exercise_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#sum
sum_num=sum(range(1,11))
print(f"Sum of first 10 natural numbers is:{sum_num}")

#factorial
num=int(input("Enter a number:"))
fact=1
for i in range(1,num+1):
 fact*=i
print(f"Factorial:{fact}")

#fibonacci series
n= int(input("enter a number:"))
x=0
y=1
print("Fibonacci Number:")
for i in range(n):
 print(x,end="")
a= x+y
x=y
y=a

#largest number
num1 = int(input("Enter a first number : "))
num2 = int(input("Enter a second number : "))
num3 = int(input("Enter a third number : "))
if num1>num2 and num1>num3:
  print(f"First number ({num1}) is the largest.")
elif num2>num1 and num2>num3:
  print(f"Second number ({num2}) is the largest.")
else:
  print(f"Third number ({num3}) is the largest.")

#Student system
print("Enter Student Details")
name=input("Enter student name:")
roll=input("Enter roll number:")
print("\nEnter marks for 5 subjects:")
sub1=float(input("Subject1:"))
sub2=float(input("Subject2:"))
sub3=float(input("Subject3:"))
sub4=float(input("Subject4:"))
sub5=float(input("Subject5:"))
total=sub1+sub2+sub3+sub4+sub5
percentage=total/5
if percentage>=90:
 grade="A+"
elif percentage>=80:
 grade="A"
elif percentage>=70:
 grade="B"
elif percentage>=60:
 grade="C"
elif percentage>=50:
 grade="D"
else:
 grade="Fail"
print("\nResult")
print("Name:",name)
print("Roll No:",roll)
print("Total Marks:",total)
print("Percentage:",percentage)
print("Grade:",grade)
# Out:
# Sum of first 10 natural numbers is:55
# Enter a number:4
# Factorial:24
# enter a number:3
# Fibonacci Number:
# 000Enter a first number : 7
# Enter a second number : 9
# Enter a third number : 20
# Third number (20) is the largest.
# Enter Student Details
# Enter student name:ADVIKA
# Enter roll number:11
#
# Enter marks for 5 subjects:
# Subject1:78
# Subject2:74
# Subject3:85
# Subject4:81
# Subject5:79
#
# Result
# Name: ADVIKA
# Roll No: 11
# Total Marks: 397.0
# Percentage: 79.4
# Grade: B
